# %% [markdown]
# ### Retrieve raw HTML from main page

# %%
from selenium import webdriver

# set the url of the website to fetch
url = 'https://www.classcentral.com'

# create a new Chrome browser instance
browser = webdriver.Chrome()
browser.implicitly_wait(5)

# navigate to the website
browser.get(url)

# get the raw HTML content
html = browser.page_source

# close the browser
browser.quit()

with open('website-A.html', 'w', encoding='utf-8') as file:
    file.write(str(html))

# %% [markdown]
# ### Parse the website to find translatable tags

# %%
from bs4 import BeautifulSoup
import requests

# Scrape the website A
# soup = BeautifulSoup(html, 'html.parser')
file = open('website-A.html', 'r', encoding='utf-8')
soup = BeautifulSoup(file, 'html.parser')
file.close()

nombres = [tag.name for tag in soup.find_all()]
nombres_unicos = []
for nombre in nombres:
    if not nombre in nombres_unicos: nombres_unicos.append(nombre)

print(f'All tags: {nombres_unicos}')
# Out:
# All tags: ['html', 'head', 'meta', 'title', 'link', 'script', 'style', 'body', 'div', 'header', 'nav', 'a', 'i', 'span', 'button', 'h2', 'section', 'ul', 'li', 'h3', 'p', 'img', 'h4', 'time', 'h5', 'ol', 'main', 'form', 'input', 'picture', 'source', 'strong', 'svg', 'path', 'aside', 'footer', 'noscript']

# %%
# Show the list of values by tag
tag_to_show = "noscript"
found = soup.find_all(name=tag_to_show)
found
# Out:
# [<noscript><p><img alt="Clicky" height="1" src="//in.getclicky.com/100717250ns.gif" width="1"/></p></noscript>]

# %%
TRANSLATABLE_TAGS = ['a', 'meta', 'title', 'span', 'button', 'h2', 'section', 'ul', 'li', 'h3', 'p', 'h4', 'h5', 'ol', 'aside', 'footer']

# %% [markdown]
# ### Translate those tags

# %% [markdown]
# #### First define a translation/post-processing function

# %%
def validate_tag(tag) -> bool:
    if tag.string is None: return False

    if tag.name == 'meta':
        return True if tag.string.starts_with("Class Central") else False
        
    print(f'nuevo tag {tag.name} encontrado: \n\t{tag.string}')
    print(f'\t{tag.get_text()}')
    return True

# %%
from google.cloud import translate_v2 as translate
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "norse-coral-377922-03fa1bb10bdb.json"

# Set up the Google Cloud Translation API client
client = translate.Client()

def do_translation(text_input: str, lan: str) -> str:
    translation = client.translate(text_input, target_language=lan) # translate the text using the Google Translate API
    translated_text = translation['translatedText'].replace('&quot;', '"')
    print(f'\ttraduccion: \n\t{translated_text}')
    
    return translated_text

# %% [markdown]
# #### Then set target language and call the translation function

# %%
TARGET_LANGUAGE = 'es'

# Translate the text of the website A
for tag in soup.find_all(TRANSLATABLE_TAGS): # loop over isolated tags
    if not validate_tag(tag): continue
    tag.string = do_translation(text_input=tag.string, lan=TARGET_LANGUAGE)
# Out:
# nuevo tag title encontrado:
# 	Class Central • Find the best courses, wherever they exist.
# 	Class Central • Find the best courses, wherever they exist.
# 	traduccion:
# 	Class Central • Encuentra los mejores cursos, dondequiera que existan.
# nuevo tag span encontrado:
# 	Class Central
# 	Class Central
# 	traduccion:
# 	centro de clase
# nuevo tag button encontrado:
#
#             Courses
#
#
#             Courses
#
# 	traduccion:
# 	Cursos
# nuevo tag h2 encontrado:
# 	Class Central
# 	Class Central
# 	traduccion:
# 	centro de clase
# nuevo tag span encontrado:
# 	Rankings
# 	Rankings
# 	traduccion:
# 	clasificaciones
# nuevo tag span encontrado:
# 	Collections
# 	Collections
# 	traduccion:
# 	Colecciones
# nuevo tag h3 encontrado:
# 	Subjects
# 	Subjects
# 	traduccion:
# 	Asignaturas
# nuevo tag a encontrado:
# 	View all
# 	View all
# 	traduccion:
# 	Ver todo
# nuevo tag span encontrado:
# 	Computer Science
# 	Computer Science
# 	traduccion:
# 	Ciencias de la Computación
# nuevo tag span encontrado:
# 	Health & Medicine
# 	Health & Medicine
# 	traduccion:
# 	Salud y Medicina
# nuevo tag span encontrado:
# 	Mathematics
# 	Mathematics
# 	traduccion:
# 	Matemáticas
# nuevo tag span encontrado:
# 	Business
# 	Business
# 	traduccion:
# 	Negocio
# nuevo tag span encontrado:
# 	Humanities
# 	Humanities
# 	traduccion:
# 	Humanidades
# nuevo tag span encontrado:
# 	Engineering
# 	Engineering
# 	traduccion:
# 	Ingeniería
# nuevo tag span encontrado:
# 	Science
# 	Science
# 	traduccion:
# 	Ciencia
# nuevo tag span encontrado:
# 	Education & Teaching
# 	Education & Teaching
# 	traduccion:
# 	Educación y Enseñanza
# nuevo tag span encontrado:
# 	Social Sciences
# 	Social Sciences
# 	traduccion:
# 	Ciencias Sociales
# nuevo tag span encontrado:
# 	Art & Design
# 	Art & Design
# 	traduccion:
# 	Diseño artístico
# nuevo tag span encontrado:
# 	Data Science
# 	Data Science
# 	traduccion:
# 	Ciencia de los datos
# nuevo tag span encontrado:
# 	Programming
# 	Programming
# 	traduccion:
# 	Programación
# nuevo tag span encontrado:
# 	Personal Development
# 	Personal Development
# 	traduccion:
# 	Desarrollo personal
# nuevo tag span encontrado:
# 	Information Security (InfoSec)
# 	Information Security (InfoSec)
# 	traduccion:
# 	Seguridad de la información (InfoSec)
# nuevo tag a encontrado:
# 	View all Subjects
# 	View all Subjects
# 	traduccion:
# 	Ver todos los temas
# nuevo tag span encontrado:
# 	Universities
# 	Universities
# 	traduccion:
# 	universidades
# nuevo tag span encontrado:
# 	The Report
# 	The Report
# 	traduccion:
# 	El informe
# nuevo tag a encontrado:
# 	1000+ universities
# 	1000+ universities
# 	traduccion:
# 	1000+ universidades
# nuevo tag h3 encontrado:
# 	Rankings
# 	Rankings
# 	traduccion:
# 	clasificaciones
# nuevo tag h3 encontrado:
# 	Best Courses
# 	Best Courses
# 	traduccion:
# 	Mejores cursos
# nuevo tag span encontrado:
# 	Best of All Time
# 	Best of All Time
# 	traduccion:
# 	Lo mejor de todos los tiempos
# nuevo tag span encontrado:
# 	Best of the Year 2022
# 	Best of the Year 2022
# 	traduccion:
# 	Lo mejor del año 2022
# nuevo tag span encontrado:
# 	Best of the Year 2021
# 	Best of the Year 2021
# 	traduccion:
# 	Lo mejor del año 2021
# nuevo tag h3 encontrado:
# 	Most Popular Courses
# 	Most Popular Courses
# 	traduccion:
# 	Cursos más populares
# nuevo tag span encontrado:
# 	Most Popular of All Time
# 	Most Popular of All Time
# 	traduccion:
# 	Más popular de todos los tiempos
# nuevo tag span encontrado:
# 	Most Popular of the Year 2022
# 	Most Popular of the Year 2022
# 	traduccion:
# 	Lo más popular del año 2022
# nuevo tag span encontrado:
# 	Most Popular of the Year 2021
# 	Most Popular of the Year 2021
# 	traduccion:
# 	Lo más popular del año 2021
# nuevo tag h3 encontrado:
# 	Collections
# 	Collections
# 	traduccion:
# 	Colecciones
# nuevo tag h3 encontrado:
# 	Monthly Course Reports
# 	Monthly Course Reports
# 	traduccion:
# 	Informes mensuales del curso
# nuevo tag span encontrado:
# 	Starting this Month
# 	Starting this Month
# 	traduccion:
# 	A partir de este mes
# nuevo tag span encontrado:
# 	New Online Courses
# 	New Online Courses
# 	traduccion:
# 	Nuevos cursos en línea
# nuevo tag span encontrado:
# 	Most Popular
# 	Most Popular
# 	traduccion:
# 	Más popular
# nuevo tag h3 encontrado:
# 	Computer Science
# 	Computer Science
# 	traduccion:
# 	Ciencias de la Computación
# nuevo tag span encontrado:
# 	Artificial Intelligence
# 	Artificial Intelligence
# 	traduccion:
# 	Inteligencia artificial
# nuevo tag span encontrado:
# 	Algorithms and Data Structures
# 	Algorithms and Data Structures
# 	traduccion:
# 	Algoritmos y estructuras de datos
# nuevo tag span encontrado:
# 	Internet of Things
# 	Internet of Things
# 	traduccion:
# 	Internet de las Cosas
# nuevo tag span encontrado:
# 	Information Technology
# 	Information Technology
# 	traduccion:
# 	Tecnologías de la información
# nuevo tag span encontrado:
# 	Computer Networking
# 	Computer Networking
# 	traduccion:
# 	Redes de computadoras
# nuevo tag span encontrado:
# 	Machine Learning
# 	Machine Learning
# 	traduccion:
# 	Aprendizaje automático
# nuevo tag span encontrado:
# 	DevOps
# 	DevOps
# 	traduccion:
# 	DevOps
# nuevo tag span encontrado:
# 	Deep Learning
# 	Deep Learning
# 	traduccion:
# 	Aprendizaje profundo
# nuevo tag span encontrado:
# 	Cryptography
# 	Cryptography
# 	traduccion:
# 	Criptografía
# nuevo tag span encontrado:
# 	Quantum Computing
# 	Quantum Computing
# 	traduccion:
# 	Computación cuántica
# nuevo tag span encontrado:
# 	Human-Computer Interaction (HCI)
# 	Human-Computer Interaction (HCI)
# 	traduccion:
# 	Interacción hombre-computadora (HCI)
# nuevo tag span encontrado:
# 	Distributed Systems
# 	Distributed Systems
# 	traduccion:
# 	Sistemas distribuidos
# nuevo tag span encontrado:
# 	Blockchain Development
# 	Blockchain Development
# 	traduccion:
# 	Desarrollo de cadena de bloques
# nuevo tag span encontrado:
# 	Operating Systems
# 	Operating Systems
# 	traduccion:
# 	Sistemas operativos
# nuevo tag span encontrado:
# 	Computer Graphics
# 	Computer Graphics
# 	traduccion:
# 	Gráficos de computadora
# nuevo tag span encontrado:
# 	View all Computer Science
# 	View all Computer Science
# 	traduccion:
# 	Ver todo Informática
# nuevo tag h3 encontrado:
# 	Health & Medicine
# 	Health & Medicine
# 	traduccion:
# 	Salud y Medicina
# nuevo tag span encontrado:
# 	Nutrition & Wellness
# 	Nutrition & Wellness
# 	traduccion:
# 	Nutrición y Bienestar
# nuevo tag span encontrado:
# 	Disease & Disorders
# 	Disease & Disorders
# 	traduccion:
# 	Enfermedades y Trastornos
# nuevo tag span encontrado:
# 	Public Health
# 	Public Health
# 	traduccion:
# 	Salud pública
# nuevo tag span encontrado:
# 	Health Care
# 	Health Care
# 	traduccion:
# 	Cuidado de la salud
# nuevo tag span encontrado:
# 	Nursing
# 	Nursing
# 	traduccion:
# 	Enfermería
# nuevo tag span encontrado:
# 	Anatomy
# 	Anatomy
# 	traduccion:
# 	Anatomía
# nuevo tag span encontrado:
# 	Veterinary Science
# 	Veterinary Science
# 	traduccion:
# 	Ciencia veterinaria
# nuevo tag span encontrado:
# 	Continuing Medical Education (CME)
# 	Continuing Medical Education (CME)
# 	traduccion:
# 	Educación Médica Continua (CME)
# nuevo tag span encontrado:
# 	View all Health & Medicine
# 	View all Health & Medicine
# 	traduccion:
# 	Ver todo Salud y Medicina
# nuevo tag h3 encontrado:
# 	Mathematics
# 	Mathematics
# 	traduccion:
# 	Matemáticas
# nuevo tag span encontrado:
# 	Statistics & Probability
# 	Statistics & Probability
# 	traduccion:
# 	Estadística y Probabilidad
# nuevo tag span encontrado:
# 	Foundations of Mathematics
# 	Foundations of Mathematics
# 	traduccion:
# 	Fundamentos de Matemáticas
# nuevo tag span encontrado:
# 	Calculus
# 	Calculus
# 	traduccion:
# 	Cálculo
# nuevo tag span encontrado:
# 	Discrete Mathematics
# 	Discrete Mathematics
# 	traduccion:
# 	Matemáticas discretas
# nuevo tag span encontrado:
# 	Trigonometry
# 	Trigonometry
# 	traduccion:
# 	Trigonometría
# nuevo tag span encontrado:
# 	Geometry
# 	Geometry
# 	traduccion:
# 	Geometría
# nuevo tag span encontrado:
# 	Algebra
# 	Algebra
# 	traduccion:
# 	Álgebra
# nuevo tag span encontrado:
# 	Precalculus
# 	Precalculus
# 	traduccion:
# 	Precalculus
# nuevo tag span encontrado:
# 	Number Theory
# 	Number Theory
# 	traduccion:
# 	Teoría de los números
# nuevo tag span encontrado:
# 	Combinatorics
# 	Combinatorics
# 	traduccion:
# 	combinatoria
# nuevo tag span encontrado:
# 	Mathematical logic
# 	Mathematical logic
# 	traduccion:
# 	lógica matemática
# nuevo tag span encontrado:
# 	Linear Programming
# 	Linear Programming
# 	traduccion:
# 	Programación lineal
# nuevo tag span encontrado:
# 	View all Mathematics
# 	View all Mathematics
# 	traduccion:
# 	Ver todo Matemáticas
# nuevo tag h3 encontrado:
# 	Business
# 	Business
# 	traduccion:
# 	Negocio
# nuevo tag span encontrado:
# 	Management & Leadership
# 	Management & Leadership
# 	traduccion:
# 	Liderazgo de la dirección
# nuevo tag span encontrado:
# 	Finance
# 	Finance
# 	traduccion:
# 	Finanzas
# nuevo tag span encontrado:
# 	Entrepreneurship
# 	Entrepreneurship
# 	traduccion:
# 	Emprendimiento
# nuevo tag span encontrado:
# 	Marketing
# 	Marketing
# 	traduccion:
# 	Marketing
# nuevo tag span encontrado:
# 	Strategic Management
# 	Strategic Management
# 	traduccion:
# 	Gestión estratégica
# nuevo tag span encontrado:
# 	Industry Specific
# 	Industry Specific
# 	traduccion:
# 	Específico de la industria
# nuevo tag span encontrado:
# 	Business Intelligence
# 	Business Intelligence
# 	traduccion:
# 	Inteligencia de Negocio
# nuevo tag span encontrado:
# 	Accounting
# 	Accounting
# 	traduccion:
# 	Contabilidad
# nuevo tag span encontrado:
# 	Human Resources
# 	Human Resources
# 	traduccion:
# 	Recursos humanos
# nuevo tag span encontrado:
# 	Project Management
# 	Project Management
# 	traduccion:
# 	Gestión de proyectos
# nuevo tag span encontrado:
# 	Sales
# 	Sales
# 	traduccion:
# 	Ventas
# nuevo tag span encontrado:
# 	Design Thinking
# 	Design Thinking
# 	traduccion:
# 	El pensamiento de diseño
# nuevo tag span encontrado:
# 	Business Software
# 	Business Software
# 	traduccion:
# 	Software de negocios
# nuevo tag span encontrado:
# 	Risk Management
# 	Risk Management
# 	traduccion:
# 	Gestión de riesgos
# nuevo tag span encontrado:
# 	Corporate Social Responsibility
# 	Corporate Social Responsibility
# 	traduccion:
# 	Responsabilidad Social Corporativa
# nuevo tag span encontrado:
# 	Customer Service
# 	Customer Service
# 	traduccion:
# 	Servicio al Cliente
# nuevo tag span encontrado:
# 	Nonprofit Management
# 	Nonprofit Management
# 	traduccion:
# 	Gestión sin fines de lucro
# nuevo tag span encontrado:
# 	Innovation
# 	Innovation
# 	traduccion:
# 	Innovación
# nuevo tag span encontrado:
# 	Operations Management
# 	Operations Management
# 	traduccion:
# 	Jefe de operaciones
# nuevo tag span encontrado:
# 	View all Business
# 	View all Business
# 	traduccion:
# 	Ver todos los Negocios
# nuevo tag h3 encontrado:
# 	Humanities
# 	Humanities
# 	traduccion:
# 	Humanidades
# nuevo tag span encontrado:
# 	History
# 	History
# 	traduccion:
# 	Historia
# nuevo tag span encontrado:
# 	Literature
# 	Literature
# 	traduccion:
# 	Literatura
# nuevo tag span encontrado:
# 	Language Learning
# 	Language Learning
# 	traduccion:
# 	Aprendizaje de idiomas
# nuevo tag span encontrado:
# 	Grammar & Writing
# 	Grammar & Writing
# 	traduccion:
# 	Gramática y Escritura
# nuevo tag span encontrado:
# 	Philosophy
# 	Philosophy
# 	traduccion:
# 	Filosofía
# nuevo tag span encontrado:
# 	Religion
# 	Religion
# 	traduccion:
# 	Religión
# nuevo tag span encontrado:
# 	ESL
# 	ESL
# 	traduccion:
# 	ESL
# nuevo tag span encontrado:
# 	Culture
# 	Culture
# 	traduccion:
# 	Cultura
# nuevo tag span encontrado:
# 	Sports
# 	Sports
# 	traduccion:
# 	Deportes
# nuevo tag span encontrado:
# 	Journalism
# 	Journalism
# 	traduccion:
# 	Periodismo
# nuevo tag span encontrado:
# 	Ethics
# 	Ethics
# 	traduccion:
# 	Ética
# nuevo tag span encontrado:
# 	Linguistics
# 	Linguistics
# 	traduccion:
# 	Lingüística
# nuevo tag span encontrado:
# 	Food
# 	Food
# 	traduccion:
# 	Alimento
# nuevo tag span encontrado:
# 	Library Science
# 	Library Science
# 	traduccion:
# 	La ciencia de la biblioteca
# nuevo tag span encontrado:
# 	Reading
# 	Reading
# 	traduccion:
# 	Lectura
# nuevo tag span encontrado:
# 	Crisis Management
# 	Crisis Management
# 	traduccion:
# 	Gestión de crisis
# nuevo tag span encontrado:
# 	View all Humanities
# 	View all Humanities
# 	traduccion:
# 	Ver todo Humanidades
# nuevo tag h3 encontrado:
# 	Engineering
# 	Engineering
# 	traduccion:
# 	Ingeniería
# nuevo tag span encontrado:
# 	Electrical Engineering
# 	Electrical Engineering
# 	traduccion:
# 	Ingenieria Eléctrica
# nuevo tag span encontrado:
# 	Mechanical Engineering
# 	Mechanical Engineering
# 	traduccion:
# 	Ingeniería Mecánica
# nuevo tag span encontrado:
# 	Civil Engineering
# 	Civil Engineering
# 	traduccion:
# 	Ingeniería civil
# nuevo tag span encontrado:
# 	Robotics
# 	Robotics
# 	traduccion:
# 	robótica
# nuevo tag span encontrado:
# 	Nanotechnology
# 	Nanotechnology
# 	traduccion:
# 	Nanotecnología
# nuevo tag span encontrado:
# 	GIS
# 	GIS
# 	traduccion:
# 	SIG
# nuevo tag span encontrado:
# 	Textiles
# 	Textiles
# 	traduccion:
# 	Textiles
# nuevo tag span encontrado:
# 	Manufacturing
# 	Manufacturing
# 	traduccion:
# 	Fabricación
# nuevo tag span encontrado:
# 	BIM
# 	BIM
# 	traduccion:
# 	BIM
# nuevo tag span encontrado:
# 	CAD
# 	CAD
# 	traduccion:
# 	CANALLA
# nuevo tag span encontrado:
# 	Chemical Engineering
# 	Chemical Engineering
# 	traduccion:
# 	Ingeniería Química
# nuevo tag span encontrado:
# 	Energy Systems
# 	Energy Systems
# 	traduccion:
# 	Sistemas de energía
# nuevo tag span encontrado:
# 	Aerospace Engineering
# 	Aerospace Engineering
# 	traduccion:
# 	Ingeniería Aeroespacial
# nuevo tag span encontrado:
# 	View all Engineering
# 	View all Engineering
# 	traduccion:
# 	Ver todo Ingeniería
# nuevo tag h3 encontrado:
# 	Science
# 	Science
# 	traduccion:
# 	Ciencia
# nuevo tag span encontrado:
# 	Chemistry
# 	Chemistry
# 	traduccion:
# 	Química
# nuevo tag span encontrado:
# 	Physics
# 	Physics
# 	traduccion:
# 	Física
# nuevo tag span encontrado:
# 	Environmental Science
# 	Environmental Science
# 	traduccion:
# 	Ciencia medioambiental
# nuevo tag span encontrado:
# 	Astronomy
# 	Astronomy
# 	traduccion:
# 	Astronomía
# nuevo tag span encontrado:
# 	Biology
# 	Biology
# 	traduccion:
# 	Biología
# nuevo tag span encontrado:
# 	Agriculture
# 	Agriculture
# 	traduccion:
# 	Agricultura
# nuevo tag span encontrado:
# 	Materials Science
# 	Materials Science
# 	traduccion:
# 	Ciencia de los Materiales
# nuevo tag span encontrado:
# 	Earth Science
# 	Earth Science
# 	traduccion:
# 	ciencia de la Tierra
# nuevo tag span encontrado:
# 	Applied Science
# 	Applied Science
# 	traduccion:
# 	Ciencia aplicada
# nuevo tag span encontrado:
# 	Forensic Science
# 	Forensic Science
# 	traduccion:
# 	Ciencia forense
# nuevo tag span encontrado:
# 	View all Science
# 	View all Science
# 	traduccion:
# 	Ver todo Ciencia
# nuevo tag h3 encontrado:
# 	Education & Teaching
# 	Education & Teaching
# 	traduccion:
# 	Educación y Enseñanza
# nuevo tag span encontrado:
# 	K12
# 	K12
# 	traduccion:
# 	K12
# nuevo tag span encontrado:
# 	Higher Education
# 	Higher Education
# 	traduccion:
# 	Educación más alta
# nuevo tag span encontrado:
# 	STEM
# 	STEM
# 	traduccion:
# 	PROVENIR
# nuevo tag span encontrado:
# 	Teacher Professional Development
# 	Teacher Professional Development
# 	traduccion:
# 	Desarrollo profesional docente
# nuevo tag span encontrado:
# 	Course Development
# 	Course Development
# 	traduccion:
# 	Desarrollo del curso
# nuevo tag span encontrado:
# 	Online Education
# 	Online Education
# 	traduccion:
# 	Educación en línea
# nuevo tag span encontrado:
# 	Test Prep
# 	Test Prep
# 	traduccion:
# 	Preparación para la prueba
# nuevo tag span encontrado:
# 	Pedagogy
# 	Pedagogy
# 	traduccion:
# 	Pedagogía
# nuevo tag span encontrado:
# 	View all Education & Teaching
# 	View all Education & Teaching
# 	traduccion:
# 	Ver todo Educación y Enseñanza
# nuevo tag h3 encontrado:
# 	Social Sciences
# 	Social Sciences
# 	traduccion:
# 	Ciencias Sociales
# nuevo tag span encontrado:
# 	Sociology
# 	Sociology
# 	traduccion:
# 	Sociología
# nuevo tag span encontrado:
# 	Economics
# 	Economics
# 	traduccion:
# 	Ciencias económicas
# nuevo tag span encontrado:
# 	Psychology
# 	Psychology
# 	traduccion:
# 	Psicología
# nuevo tag span encontrado:
# 	Anthropology
# 	Anthropology
# 	traduccion:
# 	Antropología
# nuevo tag span encontrado:
# 	Political Science
# 	Political Science
# 	traduccion:
# 	Ciencias Políticas
# nuevo tag span encontrado:
# 	Law
# 	Law
# 	traduccion:
# 	Ley
# nuevo tag span encontrado:
# 	Urban Planning
# 	Urban Planning
# 	traduccion:
# 	Urbanismo
# nuevo tag span encontrado:
# 	Human Rights
# 	Human Rights
# 	traduccion:
# 	Derechos humanos
# nuevo tag span encontrado:
# 	Sustainability
# 	Sustainability
# 	traduccion:
# 	Sostenibilidad
# nuevo tag span encontrado:
# 	Governance
# 	Governance
# 	traduccion:
# 	Gobernancia
# nuevo tag span encontrado:
# 	Archaeology
# 	Archaeology
# 	traduccion:
# 	Arqueología
# nuevo tag span encontrado:
# 	Social Work
# 	Social Work
# 	traduccion:
# 	Trabajo Social
# nuevo tag span encontrado:
# 	View all Social Sciences
# 	View all Social Sciences
# 	traduccion:
# 	Ver todo Ciencias Sociales
# nuevo tag h3 encontrado:
# 	Art & Design
# 	Art & Design
# 	traduccion:
# 	Diseño artístico
# nuevo tag span encontrado:
# 	Music
# 	Music
# 	traduccion:
# 	Música
# nuevo tag span encontrado:
# 	Digital Media
# 	Digital Media
# 	traduccion:
# 	Medios digitales
# nuevo tag span encontrado:
# 	Visual Arts
# 	Visual Arts
# 	traduccion:
# 	Artes visuales
# nuevo tag span encontrado:
# 	Design & Creativity
# 	Design & Creativity
# 	traduccion:
# 	Diseño y Creatividad
# nuevo tag span encontrado:
# 	View all Art & Design
# 	View all Art & Design
# 	traduccion:
# 	Ver todo Arte y Diseño
# nuevo tag h3 encontrado:
# 	Data Science
# 	Data Science
# 	traduccion:
# 	Ciencia de los datos
# nuevo tag span encontrado:
# 	Bioinformatics
# 	Bioinformatics
# 	traduccion:
# 	Bioinformática
# nuevo tag span encontrado:
# 	Big Data
# 	Big Data
# 	traduccion:
# 	Grandes datos
# nuevo tag span encontrado:
# 	Data Mining
# 	Data Mining
# 	traduccion:
# 	Procesamiento de datos
# nuevo tag span encontrado:
# 	Data Analysis
# 	Data Analysis
# 	traduccion:
# 	Análisis de los datos
# nuevo tag span encontrado:
# 	Data Visualization
# 	Data Visualization
# 	traduccion:
# 	Visualización de datos
# nuevo tag span encontrado:
# 	Jupyter Notebooks
# 	Jupyter Notebooks
# 	traduccion:
# 	Cuadernos Jupyter
# nuevo tag span encontrado:
# 	View all Data Science
# 	View all Data Science
# 	traduccion:
# 	Ver todo Ciencia de datos
# nuevo tag h3 encontrado:
# 	Programming
# 	Programming
# 	traduccion:
# 	Programación
# nuevo tag span encontrado:
# 	Mobile Development
# 	Mobile Development
# 	traduccion:
# 	Desarrollo móvil
# nuevo tag span encontrado:
# 	Web Development
# 	Web Development
# 	traduccion:
# 	Desarrollo web
# nuevo tag span encontrado:
# 	Databases
# 	Databases
# 	traduccion:
# 	bases de datos
# nuevo tag span encontrado:
# 	Game Development
# 	Game Development
# 	traduccion:
# 	Desarrollo de juegos
# nuevo tag span encontrado:
# 	Programming Languages
# 	Programming Languages
# 	traduccion:
# 	Lenguajes de programación
# nuevo tag span encontrado:
# 	Software Development
# 	Software Development
# 	traduccion:
# 	Desarrollo de software
# nuevo tag span encontrado:
# 	Cloud Computing
# 	Cloud Computing
# 	traduccion:
# 	Computación en la nube
# nuevo tag span encontrado:
# 	View all Programming
# 	View all Programming
# 	traduccion:
# 	Ver toda la Programación
# nuevo tag h3 encontrado:
# 	Personal Development
# 	Personal Development
# 	traduccion:
# 	Desarrollo personal
# nuevo tag span encontrado:
# 	Communication Skills
# 	Communication Skills
# 	traduccion:
# 	Habilidades de comunicación
# nuevo tag span encontrado:
# 	Career Development
# 	Career Development
# 	traduccion:
# 	Desarrollo de carrera
# nuevo tag span encontrado:
# 	Self Improvement
# 	Self Improvement
# 	traduccion:
# 	superación personal
# nuevo tag span encontrado:
# 	Presentation Skills
# 	Presentation Skills
# 	traduccion:
# 	Habilidades de presentación
# nuevo tag span encontrado:
# 	Resilience
# 	Resilience
# 	traduccion:
# 	Resiliencia
# nuevo tag span encontrado:
# 	View all Personal Development
# 	View all Personal Development
# 	traduccion:
# 	Ver todo Desarrollo Personal
# nuevo tag h3 encontrado:
# 	Information Security (InfoSec)
# 	Information Security (InfoSec)
# 	traduccion:
# 	Seguridad de la información (InfoSec)
# nuevo tag span encontrado:
# 	Cybersecurity
# 	Cybersecurity
# 	traduccion:
# 	La seguridad cibernética
# nuevo tag span encontrado:
# 	Network Security
# 	Network Security
# 	traduccion:
# 	Seguridad de la red
# nuevo tag span encontrado:
# 	Ethical Hacking
# 	Ethical Hacking
# 	traduccion:
# 	Hackeo ético
# nuevo tag span encontrado:
# 	Digital Forensics
# 	Digital Forensics
# 	traduccion:
# 	Forense digital
# nuevo tag span encontrado:
# 	Reverse Engineering
# 	Reverse Engineering
# 	traduccion:
# 	Ingeniería inversa
# nuevo tag span encontrado:
# 	Penetration Testing
# 	Penetration Testing
# 	traduccion:
# 	Pruebas de penetración
# nuevo tag span encontrado:
# 	Malware Analysis
# 	Malware Analysis
# 	traduccion:
# 	Análisis de malware
# nuevo tag span encontrado:
# 	DevSecOps
# 	DevSecOps
# 	traduccion:
# 	DevSecOps
# nuevo tag span encontrado:
# 	OSINT (Open Source Intelligence)
# 	OSINT (Open Source Intelligence)
# 	traduccion:
# 	OSINT (Inteligencia de código abierto)
# nuevo tag span encontrado:
# 	Threat Intelligence
# 	Threat Intelligence
# 	traduccion:
# 	Inteligencia de amenazas
# nuevo tag span encontrado:
# 	Information Security Certifications
# 	Information Security Certifications
# 	traduccion:
# 	Certificaciones de seguridad de la información
# nuevo tag span encontrado:
# 	Red Team
# 	Red Team
# 	traduccion:
# 	equipo rojo
# nuevo tag span encontrado:
# 	Blue Team
# 	Blue Team
# 	traduccion:
# 	Equipo azul
# nuevo tag span encontrado:
# 	View all Information Security (InfoSec)
# 	View all Information Security (InfoSec)
# 	traduccion:
# 	Ver todo Seguridad de la información (InfoSec)
# nuevo tag a encontrado:
#
#             The Report
#
#
#             The Report
#
# 	traduccion:
# 	El informe
# nuevo tag a encontrado:
#
#           2022 Year in Review: The “New Normal” that Wasn’t
#
#
#           2022 Year in Review: The “New Normal” that Wasn’t
#
# 	traduccion:
# 	Resumen del año 2022: la "nueva normalidad" que no fue
# nuevo tag p encontrado:
# 	The pandemic ushered in a “new normal” in online learning, but it culminated in layoffs and stock drops.
#
# 	The pandemic ushered in a “new normal” in online learning, but it culminated in layoffs and stock drops.
#
# 	traduccion:
# 	La pandemia marcó el comienzo de una "nueva normalidad" en el aprendizaje en línea, pero culminó en despidos y caídas de existencias.
# nuevo tag a encontrado:
#
#           Dhawal Shah
#
#
#           Dhawal Shah
#
# 	traduccion:
# 	Dhawal Shah
# nuevo tag h5 encontrado:
# 	Latest
# 	Latest
# 	traduccion:
# 	El último
# nuevo tag a encontrado:
# 	Empowering Future Educators: A Review of ‘Learning to Teach – Mentoring and Tutoring Student Teachers’
# 	Empowering Future Educators: A Review of ‘Learning to Teach – Mentoring and Tutoring Student Teachers’
# 	traduccion:
# 	Empoderar a los futuros educadores: una revisión de &#39;Aprender a enseñar: tutoría y tutoría de los futuros maestros&#39;
# nuevo tag a encontrado:
# 	Udemy Lays Off ~200 Staff, After Being Only Major Player to Avoid Layoffs in 2022
# 	Udemy Lays Off ~200 Staff, After Being Only Major Player to Avoid Layoffs in 2022
# 	traduccion:
# 	Udemy despide a ~200 empleados, después de ser el único jugador importante para evitar despidos en 2022
# nuevo tag a encontrado:
# 	9 Best DaVinci Resolve Courses to Take in 2023
# 	9 Best DaVinci Resolve Courses to Take in 2023
# 	traduccion:
# 	Los 9 mejores cursos de DaVinci Resolve para tomar en 2023
# nuevo tag a encontrado:
# 	25 Most Popular Online Courses Starting in March 2023
# 	25 Most Popular Online Courses Starting in March 2023
# 	traduccion:
# 	Los 25 cursos en línea más populares a partir de marzo de 2023
# nuevo tag a encontrado:
# 	6 Best Free Prolog Courses to Take in 2023
# 	6 Best Free Prolog Courses to Take in 2023
# 	traduccion:
# 	Los 6 mejores cursos gratuitos de Prolog para tomar en 2023
# nuevo tag p encontrado:
# 	Organize and share your learning with Class Central Lists.
# 	Organize and share your learning with Class Central Lists.
# 	traduccion:
# 	Organice y comparta su aprendizaje con Class Central Lists.
# nuevo tag a encontrado:
# 	Lists Showcase
# 	Lists Showcase
# 	traduccion:
# 	Escaparate de listas
# nuevo tag a encontrado:
#
#           Sign up
#
#
#           Sign up
#
# 	traduccion:
# 	Inscribirse
# nuevo tag a encontrado:
# 	Log in
# 	Log in
# 	traduccion:
# 	Acceso
# nuevo tag span encontrado:
# 	or
# 	or
# 	traduccion:
# 	o
# nuevo tag a encontrado:
#
#                 Sign up
#
#
#                 Sign up
#
# 	traduccion:
# 	Inscribirse
# nuevo tag a encontrado:
#
#           Log in
#
#
#           Log in
#
# 	traduccion:
# 	Acceso
# nuevo tag a encontrado:
#
#           Sign up
#
#
#           Sign up
#
# 	traduccion:
# 	Inscribirse
# nuevo tag h2 encontrado:
#
#         Find your next course.
#
#
#         Find your next course.
#
# 	traduccion:
# 	Encuentra tu próximo curso.
# nuevo tag p encontrado:
# 	700+ Free Google Certifications
# 	700+ Free Google Certifications
# 	traduccion:
# 	Más de 700 certificaciones gratuitas de Google
# nuevo tag h2 encontrado:
# 	Most common
# 	Most common
# 	traduccion:
# 	Más común
# nuevo tag span encontrado:
# 	English
# 	English
# 	traduccion:
# 	Inglés
# nuevo tag span encontrado:
# 	excel
# 	excel
# 	traduccion:
# 	sobresalir
# nuevo tag span encontrado:
# 	project management
# 	project management
# 	traduccion:
# 	gestión de proyectos
# nuevo tag h2 encontrado:
# 	Popular subjects
# 	Popular subjects
# 	traduccion:
# 	Temas populares
# nuevo tag p encontrado:
# 	Information Technology (IT) Certifications
# 	Information Technology (IT) Certifications
# 	traduccion:
# 	Certificaciones de tecnología de la información (TI)
# nuevo tag span encontrado:
# 	504 courses
# 	504 courses
# 	traduccion:
# 	504 cursos
# nuevo tag p encontrado:
# 	Computer Science
# 	Computer Science
# 	traduccion:
# 	Ciencias de la Computación
# nuevo tag span encontrado:
# 	8,446 courses
# 	8,446 courses
# 	traduccion:
# 	8.446 cursos
# nuevo tag p encontrado:
# 	Programming
# 	Programming
# 	traduccion:
# 	Programación
# nuevo tag span encontrado:
# 	24,519 courses
# 	24,519 courses
# 	traduccion:
# 	24.519 cursos
# nuevo tag h2 encontrado:
# 	Popular courses
# 	Popular courses
# 	traduccion:
# 	Cursos populares
# nuevo tag p encontrado:
# 	The Modern World, Part One: Global History from 1760 to 1910
# 	The Modern World, Part One: Global History from 1760 to 1910
# 	traduccion:
# 	El mundo moderno, primera parte: Historia global de 1760 a 1910
# nuevo tag span encontrado:
# 	University of Virginia
# 	University of Virginia
# 	traduccion:
# 	Universidad de Virginia
# nuevo tag p encontrado:
# 	What is a Mind?
# 	What is a Mind?
# 	traduccion:
# 	¿Qué es una mente?
# nuevo tag span encontrado:
# 	University of Cape Town
# 	University of Cape Town
# 	traduccion:
# 	Universidad de Ciudad del Cabo
# nuevo tag p encontrado:
# 	Circular Fashion: Design, Science and Value in a Sustainable Clothing Industry
# 	Circular Fashion: Design, Science and Value in a Sustainable Clothing Industry
# 	traduccion:
# 	Moda circular: diseño, ciencia y valor en una industria textil sostenible
# nuevo tag span encontrado:
# 	Wageningen University
# 	Wageningen University
# 	traduccion:
# 	Universidad de Wageningen
# nuevo tag a encontrado:
# 	subject
# 	subject
# 	traduccion:
# 	sujeto
# nuevo tag a encontrado:
# 	university
# 	university
# 	traduccion:
# 	universidad
# nuevo tag span encontrado:
# 	Learn more
# 	Learn more
# 	traduccion:
# 	Aprende más
# nuevo tag h3 encontrado:
# 	Popular courses
# 	Popular courses
# 	traduccion:
# 	Cursos populares
# nuevo tag span encontrado:
# 	Free Certificates
# 	Free Certificates
# 	traduccion:
# 	Certificados Gratis
# nuevo tag span encontrado:
# 	Ivy League
# 	Ivy League
# 	traduccion:
# 	liga hiedra
# nuevo tag span encontrado:
# 	Stanford
# 	Stanford
# 	traduccion:
# 	Stanford
# nuevo tag span encontrado:
# 	Best of All Time
# 	Best of All Time
# 	traduccion:
# 	Lo mejor de todos los tiempos
# nuevo tag span encontrado:
# 	Computer Science
# 	Computer Science
# 	traduccion:
# 	Ciencias de la Computación
# nuevo tag span encontrado:
# 	Sustainability
# 	Sustainability
# 	traduccion:
# 	Sostenibilidad
# nuevo tag span encontrado:
# 	MIT
# 	MIT
# 	traduccion:
# 	CON
# nuevo tag span encontrado:
# 	Google
# 	Google
# 	traduccion:
# 	Google
# nuevo tag span encontrado:
# 	Amazon
# 	Amazon
# 	traduccion:
# 	Amazonas
# nuevo tag span encontrado:
# 	Business
# 	Business
# 	traduccion:
# 	Negocio
# nuevo tag span encontrado:
# 	Best Courses Guides
# 	Best Courses Guides
# 	traduccion:
# 	Las mejores guías de cursos
# nuevo tag span encontrado:
# 	Deals and Discounts
# 	Deals and Discounts
# 	traduccion:
# 	Ofertas y Descuentos
# nuevo tag h2 encontrado:
#
#         Find the best courses, wherever they exist
#
#
#         Find the best courses, wherever they exist
#
# 	traduccion:
# 	Encuentra los mejores cursos, dondequiera que existan
# nuevo tag h3 encontrado:
# 	~1000 Universities
# 	~1000 Universities
# 	traduccion:
# 	~1000 Universidades
# nuevo tag span encontrado:
#
#               Browse universities
#
#
#               Browse universities
#
# 	traduccion:
# 	Explorar universidades
# nuevo tag h3 encontrado:
# 	70 Providers
# 	70 Providers
# 	traduccion:
# 	70 proveedores
# nuevo tag span encontrado:
#
#               Browse providers
#
#
#               Browse providers
#
# 	traduccion:
# 	Explorar proveedores
# nuevo tag h3 encontrado:
# 	600+ Institutions
# 	600+ Institutions
# 	traduccion:
# 	Más de 600 instituciones
# nuevo tag span encontrado:
#
#               Browse institutions
#
#
#               Browse institutions
#
# 	traduccion:
# 	Explorar instituciones
# nuevo tag p encontrado:
#
#         Tens of thousands of reviews written by Class Central users help you pick the best course.
#
#
#         Tens of thousands of reviews written by Class Central users help you pick the best course.
#
# 	traduccion:
# 	Decenas de miles de reseñas escritas por usuarios de Class Central lo ayudan a elegir el mejor curso.
# nuevo tag span encontrado:
#
#           View rankings
#
#
#           View rankings
#
# 	traduccion:
# 	Ver clasificaciones
# nuevo tag h2 encontrado:
# 	As seen in
# 	As seen in
# 	traduccion:
# 	Como se vio en
# nuevo tag title encontrado:
# 	National Public Radio
# 	National Public Radio
# 	traduccion:
# 	Radio Pública Nacional
# nuevo tag title encontrado:
# 	CNBC
# 	CNBC
# 	traduccion:
# 	CNBC
# nuevo tag span encontrado:
# 	Class Central
# 	Class Central
# 	traduccion:
# 	centro de clase
# nuevo tag a encontrado:
#
#           free account
#
#
#           free account
#
# 	traduccion:
# 	cuenta gratis
# nuevo tag span encontrado:
# 	visitors
# 	visitors
# 	traduccion:
# 	visitantes
# nuevo tag span encontrado:
# 	sign-ups
# 	sign-ups
# 	traduccion:
# 	inscripciones
# nuevo tag span encontrado:
#
#             follows
#
#
#             follows
#
# 	traduccion:
# 	sigue
# nuevo tag span encontrado:
#
#             bookmarks
#
#
#             bookmarks
#
# 	traduccion:
# 	marcadores
# nuevo tag span encontrado:
#
#             lists created
#
#
#             lists created
#
# 	traduccion:
# 	listas creadas
# nuevo tag span encontrado:
# 	online education.
# 	online education.
# 	traduccion:
# 	educación en línea.
# nuevo tag a encontrado:
# 	RSS Feed
# 	RSS Feed
# 	traduccion:
# 	RSS Feed
# nuevo tag a encontrado:
#
#                     Udemy Lays Off ~200 Staff, After Being Only Major Player to Avoid Layoffs in 2022
#
#
#                     Udemy Lays Off ~200 Staff, After Being Only Major Player to Avoid Layoffs in 2022
#
# 	traduccion:
# 	Udemy despide a ~200 empleados, después de ser el único jugador importante para evitar despidos en 2022
# nuevo tag a encontrado:
# 	By Dhawal Shah
# 	By Dhawal Shah
# 	traduccion:
# 	Por Dhawal Shah
# nuevo tag span encontrado:
# 	By Dhawal Shah
# 	By Dhawal Shah
# 	traduccion:
# 	Por Dhawal Shah
# nuevo tag span encontrado:
# 	Feb 15th, 2023
# 	Feb 15th, 2023
# 	traduccion:
# 	15 de febrero de 2023
# nuevo tag a encontrado:
#
#                     Harvard CS50 Guide: How to Pick the Right Course (with Free Certificate)
#
#
#                     Harvard CS50 Guide: How to Pick the Right Course (with Free Certificate)
#
# 	traduccion:
# 	Guía Harvard CS50: Cómo elegir el curso adecuado (con certificado gratuito)
# nuevo tag a encontrado:
# 	By Manoel Cortes Mendez
# 	By Manoel Cortes Mendez
# 	traduccion:
# 	By Manoel Cortes Mendez
# nuevo tag span encontrado:
# 	By Manoel Cortes Mendez
# 	By Manoel Cortes Mendez
# 	traduccion:
# 	By Manoel Cortes Mendez
# nuevo tag span encontrado:
# 	Feb 7th, 2023
# 	Feb 7th, 2023
# 	traduccion:
# 	7 de febrero de 2023
# nuevo tag a encontrado:
#
#                     Massive List of Chinese Online Course Platforms in 2023
#
#
#                     Massive List of Chinese Online Course Platforms in 2023
#
# 	traduccion:
# 	Lista masiva de plataformas de cursos en línea de chino en 2023
# nuevo tag a encontrado:
# 	By Rui Ma
# 	By Rui Ma
# 	traduccion:
# 	Por Rui Ma
# nuevo tag span encontrado:
# 	By Rui Ma
# 	By Rui Ma
# 	traduccion:
# 	Por Rui Ma
# nuevo tag span encontrado:
# 	Feb 6th, 2023
# 	Feb 6th, 2023
# 	traduccion:
# 	6 de febrero de 2023
# nuevo tag a encontrado:
#
#                     FutureLearn Under New Leadership Expands Paywall, Restricts Course Binging
#
#
#                     FutureLearn Under New Leadership Expands Paywall, Restricts Course Binging
#
# 	traduccion:
# 	FutureLearn, bajo un nuevo liderazgo, amplía el muro de pago y restringe el uso intensivo de cursos
# nuevo tag a encontrado:
# 	By Pat Bowden
# 	By Pat Bowden
# 	traduccion:
# 	Por Pat Bowden
# nuevo tag span encontrado:
# 	By Pat Bowden
# 	By Pat Bowden
# 	traduccion:
# 	Por Pat Bowden
# nuevo tag span encontrado:
# 	Jan 31st, 2023
# 	Jan 31st, 2023
# 	traduccion:
# 	31 de enero de 2023
# nuevo tag a encontrado:
#
#                     202K Courses, 662M Enrollments: Breaking Down Udemy’s Massive Catalog
#
#
#                     202K Courses, 662M Enrollments: Breaking Down Udemy’s Massive Catalog
#
# 	traduccion:
# 	202 mil cursos, 662 millones de inscripciones: desglose del catálogo masivo de Udemy
# nuevo tag a encontrado:
# 	By Dhawal Shah
# 	By Dhawal Shah
# 	traduccion:
# 	Por Dhawal Shah
# nuevo tag span encontrado:
# 	By Dhawal Shah
# 	By Dhawal Shah
# 	traduccion:
# 	Por Dhawal Shah
# nuevo tag span encontrado:
# 	Jan 25th, 2023
# 	Jan 25th, 2023
# 	traduccion:
# 	25 de enero de 2023
# nuevo tag a encontrado:
#
#                     Domestika, the Online Learning Unicorn, Closes Global Offices and Downsizes Staff by 40%
#
#
#                     Domestika, the Online Learning Unicorn, Closes Global Offices and Downsizes Staff by 40%
#
# 	traduccion:
# 	Domestika, el unicornio del aprendizaje en línea, cierra oficinas globales y reduce el personal en un 40 %
# nuevo tag a encontrado:
# 	By Dhawal Shah
# 	By Dhawal Shah
# 	traduccion:
# 	Por Dhawal Shah
# nuevo tag span encontrado:
# 	By Dhawal Shah
# 	By Dhawal Shah
# 	traduccion:
# 	Por Dhawal Shah
# nuevo tag span encontrado:
# 	Jan 23rd, 2023
# 	Jan 23rd, 2023
# 	traduccion:
# 	23 de enero de 2023
# nuevo tag a encontrado:
#
#                     Thinkific Lays Off 75 More Employees, After the 100 of Last March
#
#
#                     Thinkific Lays Off 75 More Employees, After the 100 of Last March
#
# 	traduccion:
# 	Thinkific despide a 75 empleados más, tras los 100 de marzo pasado
# nuevo tag a encontrado:
# 	By Dhawal Shah
# 	By Dhawal Shah
# 	traduccion:
# 	Por Dhawal Shah
# nuevo tag span encontrado:
# 	By Dhawal Shah
# 	By Dhawal Shah
# 	traduccion:
# 	Por Dhawal Shah
# nuevo tag span encontrado:
# 	Jan 16th, 2023
# 	Jan 16th, 2023
# 	traduccion:
# 	16 de enero de 2023
# nuevo tag a encontrado:
#
#                     Udemy CEO to Retire, Replaced by President of Udemy Business
#
#
#                     Udemy CEO to Retire, Replaced by President of Udemy Business
#
# 	traduccion:
# 	El CEO de Udemy se jubilará, reemplazado por el presidente de Udemy Business
# nuevo tag a encontrado:
# 	By Dhawal Shah
# 	By Dhawal Shah
# 	traduccion:
# 	Por Dhawal Shah
# nuevo tag span encontrado:
# 	By Dhawal Shah
# 	By Dhawal Shah
# 	traduccion:
# 	Por Dhawal Shah
# nuevo tag span encontrado:
# 	Jan 11th, 2023
# 	Jan 11th, 2023
# 	traduccion:
# 	11 de enero de 2023
# nuevo tag a encontrado:
#
#                     Harvard CS50 in 2023: How to Get a Free Certificate
#
#
#                     Harvard CS50 in 2023: How to Get a Free Certificate
#
# 	traduccion:
# 	Harvard CS50 en 2023: cómo obtener un certificado gratuito
# nuevo tag a encontrado:
# 	By Manoel Cortes Mendez
# 	By Manoel Cortes Mendez
# 	traduccion:
# 	By Manoel Cortes Mendez
# nuevo tag span encontrado:
# 	By Manoel Cortes Mendez
# 	By Manoel Cortes Mendez
# 	traduccion:
# 	By Manoel Cortes Mendez
# nuevo tag span encontrado:
# 	Jan 9th, 2023
# 	Jan 9th, 2023
# 	traduccion:
# 	9 de enero de 2023
# nuevo tag h3 encontrado:
# 	Best Courses Guides
# 	Best Courses Guides
# 	traduccion:
# 	Las mejores guías de cursos
# nuevo tag a encontrado:
#
#                 9 Best DaVinci Resolve Courses
#
#
#                 9 Best DaVinci Resolve Courses
#
# 	traduccion:
# 	Los 9 mejores cursos de DaVinci Resolve
# nuevo tag span encontrado:
# 	Feb 14th, 2023
# 	Feb 14th, 2023
# 	traduccion:
# 	14 de febrero de 2023
# nuevo tag a encontrado:
#
#                 6 Best Free Prolog Courses
#
#
#                 6 Best Free Prolog Courses
#
# 	traduccion:
# 	Los 6 mejores cursos gratuitos de Prolog
# nuevo tag span encontrado:
# 	Feb 13th, 2023
# 	Feb 13th, 2023
# 	traduccion:
# 	13 de febrero de 2023
# nuevo tag a encontrado:
#
#                 10 Best Japanese Courses
#
#
#                 10 Best Japanese Courses
#
# 	traduccion:
# 	10 mejores cursos de japonés
# nuevo tag span encontrado:
# 	Feb 8th, 2023
# 	Feb 8th, 2023
# 	traduccion:
# 	8 de febrero de 2023
# nuevo tag a encontrado:
#
#                 7 Best Erlang Courses
#
#
#                 7 Best Erlang Courses
#
# 	traduccion:
# 	Los 7 mejores cursos de Erlang
# nuevo tag span encontrado:
# 	Feb 7th, 2023
# 	Feb 7th, 2023
# 	traduccion:
# 	7 de febrero de 2023
# nuevo tag a encontrado:
#
#                 10 Best CSS Animation Courses
#
#
#                 10 Best CSS Animation Courses
#
# 	traduccion:
# 	10 mejores cursos de animación CSS
# nuevo tag span encontrado:
# 	Feb 6th, 2023
# 	Feb 6th, 2023
# 	traduccion:
# 	6 de febrero de 2023
# nuevo tag span encontrado:
#
#           Browse collections
#
#
#           Browse collections
#
# 	traduccion:
# 	Explorar colecciones
# nuevo tag span encontrado:
# 	Home
# 	Home
# 	traduccion:
# 	Hogar
# nuevo tag a encontrado:
#
#                 Browse by subject
#
#
#                 Browse by subject
#
# 	traduccion:
# 	Navegar por tema
# nuevo tag a encontrado:
# 	Computer Science
# 	Computer Science
# 	traduccion:
# 	Ciencias de la Computación
# nuevo tag a encontrado:
# 	Psychology
# 	Psychology
# 	traduccion:
# 	Psicología
# nuevo tag a encontrado:
# 	Cybersecurity
# 	Cybersecurity
# 	traduccion:
# 	La seguridad cibernética
# nuevo tag a encontrado:
# 	Health
# 	Health
# 	traduccion:
# 	Salud
# nuevo tag a encontrado:
# 	Law
# 	Law
# 	traduccion:
# 	Ley
# nuevo tag a encontrado:
# 	Accounting
# 	Accounting
# 	traduccion:
# 	Contabilidad
# nuevo tag a encontrado:
# 	Web Development
# 	Web Development
# 	traduccion:
# 	Desarrollo web
# nuevo tag a encontrado:
#
#                 Browse by provider
#
#
#                 Browse by provider
#
# 	traduccion:
# 	Navegar por proveedor
# nuevo tag a encontrado:
# 	Coursera
# 	Coursera
# 	traduccion:
# 	Coursera
# nuevo tag a encontrado:
# 	edX
# 	edX
# 	traduccion:
# 	edX
# nuevo tag a encontrado:
# 	FutureLearn
# 	FutureLearn
# 	traduccion:
# 	FuturoAprender
# nuevo tag a encontrado:
# 	Udacity
# 	Udacity
# 	traduccion:
# 	audacia
# nuevo tag a encontrado:
# 	Swayam
# 	Swayam
# 	traduccion:
# 	Swayam
# nuevo tag a encontrado:
# 	Udemy
# 	Udemy
# 	traduccion:
# 	Udemy
# nuevo tag a encontrado:
# 	LinkedIn Learning
# 	LinkedIn Learning
# 	traduccion:
# 	Aprendizaje de LinkedIn
# nuevo tag a encontrado:
#
#                 Browse by university
#
#
#                 Browse by university
#
# 	traduccion:
# 	Navegar por universidad
# nuevo tag a encontrado:
# 	Harvard
# 	Harvard
# 	traduccion:
# 	harvard
# nuevo tag a encontrado:
# 	Stanford
# 	Stanford
# 	traduccion:
# 	Stanford
# nuevo tag a encontrado:
# 	Georgia Tech
# 	Georgia Tech
# 	traduccion:
# 	tecnología de georgia
# nuevo tag a encontrado:
# 	University of Michigan
# 	University of Michigan
# 	traduccion:
# 	Universidad de Michigan
# nuevo tag a encontrado:
# 	Purdue University
# 	Purdue University
# 	traduccion:
# 	Universidad de Purdue
# nuevo tag a encontrado:
# 	Duke University
# 	Duke University
# 	traduccion:
# 	Universidad de Duke
# nuevo tag a encontrado:
# 	IIT Madras
# 	IIT Madras
# 	traduccion:
# 	IIT Madrás
# nuevo tag a encontrado:
#
#                 Browse by institution
#
#
#                 Browse by institution
#
# 	traduccion:
# 	Navegar por institución
# nuevo tag a encontrado:
# 	Google
# 	Google
# 	traduccion:
# 	Google
# nuevo tag a encontrado:
# 	Microsoft
# 	Microsoft
# 	traduccion:
# 	microsoft
# nuevo tag a encontrado:
# 	IBM
# 	IBM
# 	traduccion:
# 	IBM
# nuevo tag a encontrado:
# 	Amazon
# 	Amazon
# 	traduccion:
# 	Amazonas
# nuevo tag a encontrado:
# 	Linux Foundation
# 	Linux Foundation
# 	traduccion:
# 	Fundación Linux
# nuevo tag a encontrado:
# 	British Council
# 	British Council
# 	traduccion:
# 	Consejo Británico
# nuevo tag a encontrado:
# 	Salesforce
# 	Salesforce
# 	traduccion:
# 	Fuerza de ventas
# nuevo tag a encontrado:
#
#                 Rankings
#
#
#                 Rankings
#
# 	traduccion:
# 	clasificaciones
# nuevo tag a encontrado:
# 	Best Online Courses of All Time
# 	Best Online Courses of All Time
# 	traduccion:
# 	Los mejores cursos en línea de todos los tiempos
# nuevo tag a encontrado:
# 	Best Online Courses of the Year
# 	Best Online Courses of the Year
# 	traduccion:
# 	Los mejores cursos en línea del año
# nuevo tag a encontrado:
# 	Most Popular Courses of All Time
# 	Most Popular Courses of All Time
# 	traduccion:
# 	Cursos más populares de todos los tiempos
# nuevo tag a encontrado:
# 	Most Popular Courses of the Year
# 	Most Popular Courses of the Year
# 	traduccion:
# 	Cursos más populares del año
# nuevo tag a encontrado:
# 	250 Top FREE Coursera Courses of All Time
# 	250 Top FREE Coursera Courses of All Time
# 	traduccion:
# 	Los 250 mejores cursos GRATUITOS de Coursera de todos los tiempos
# nuevo tag a encontrado:
# 	100 Top FREE edX Courses of All Time
# 	100 Top FREE edX Courses of All Time
# 	traduccion:
# 	Los 100 mejores cursos GRATUITOS de edX de todos los tiempos
# nuevo tag a encontrado:
# 	250 Top Udemy Courses of All Time
# 	250 Top Udemy Courses of All Time
# 	traduccion:
# 	Los 250 mejores cursos de Udemy de todos los tiempos
# nuevo tag a encontrado:
#
#                 RSS Feed
#
#
#                 RSS Feed
#
# 	traduccion:
# 	RSS Feed
# nuevo tag a encontrado:
# 	The "New Normal" that Wasn't
# 	The "New Normal" that Wasn't
# 	traduccion:
# 	La "nueva normalidad" que no fue
# nuevo tag a encontrado:
# 	DDoS Attack on Class Central
# 	DDoS Attack on Class Central
# 	traduccion:
# 	Ataque DDoS en Class Central
# nuevo tag a encontrado:
# 	500+ Online Degrees in India
# 	500+ Online Degrees in India
# 	traduccion:
# 	Más de 500 títulos en línea en la India
# nuevo tag a encontrado:
# 	Harvard's CS50 Free Certificate Guide
# 	Harvard's CS50 Free Certificate Guide
# 	traduccion:
# 	Guía de certificados gratuitos CS50 de Harvard
# nuevo tag a encontrado:
# 	How Open University Works
# 	How Open University Works
# 	traduccion:
# 	Cómo funciona la Universidad Abierta
# nuevo tag a encontrado:
# 	Free Certificates & Courses
# 	Free Certificates & Courses
# 	traduccion:
# 	Certificados y cursos gratuitos
# nuevo tag a encontrado:
# 	700+ Free Google Certificates
# 	700+ Free Google Certificates
# 	traduccion:
# 	Más de 700 certificados de Google gratuitos
# nuevo tag a encontrado:
# 	Free LinkedIn Learning Certificates
# 	Free LinkedIn Learning Certificates
# 	traduccion:
# 	Certificados gratuitos de aprendizaje de LinkedIn
# nuevo tag a encontrado:
# 	1600+ Free Coursera Courses
# 	1600+ Free Coursera Courses
# 	traduccion:
# 	Más de 1600 cursos gratuitos de Coursera
# nuevo tag a encontrado:
# 	Ivy League Online Courses
# 	Ivy League Online Courses
# 	traduccion:
# 	Cursos en línea de la Ivy League
# nuevo tag a encontrado:
# 	175+ Free Writing Online Courses
# 	175+ Free Writing Online Courses
# 	traduccion:
# 	Más de 175 cursos gratuitos de escritura en línea
# nuevo tag a encontrado:
#
#                 About Class Central
#
#
#                 About Class Central
#
# 	traduccion:
# 	Acerca de Class Central
# nuevo tag p encontrado:
# 	Class Central aggregates courses from many providers to help you find the best courses on almost any subject, wherever they exist.
# 	Class Central aggregates courses from many providers to help you find the best courses on almost any subject, wherever they exist.
# 	traduccion:
# 	Class Central agrega cursos de muchos proveedores para ayudarlo a encontrar los mejores cursos sobre casi cualquier tema, dondequiera que existan.
# nuevo tag li encontrado:
# 	Facebook
# 	Facebook
# 	traduccion:
# 	Facebook
# nuevo tag a encontrado:
# 	Facebook
# 	Facebook
# 	traduccion:
# 	Facebook
# nuevo tag li encontrado:
# 	Twitter
# 	Twitter
# 	traduccion:
# 	Gorjeo
# nuevo tag a encontrado:
# 	Twitter
# 	Twitter
# 	traduccion:
# 	Gorjeo
# nuevo tag li encontrado:
# 	LinkedIn
# 	LinkedIn
# 	traduccion:
# 	LinkedIn
# nuevo tag a encontrado:
# 	LinkedIn
# 	LinkedIn
# 	traduccion:
# 	LinkedIn
# nuevo tag li encontrado:
# 	YouTube
# 	YouTube
# 	traduccion:
# 	YouTube
# nuevo tag a encontrado:
# 	YouTube
# 	YouTube
# 	traduccion:
# 	YouTube
# nuevo tag a encontrado:
# 	Privacy Policy
# 	Privacy Policy
# 	traduccion:
# 	política de privacidad
# nuevo tag a encontrado:
# 	About Us
# 	About Us
# 	traduccion:
# 	Sobre nosotros
# nuevo tag a encontrado:
# 	Join Us
# 	Join Us
# 	traduccion:
# 	Únete a nosotros
# nuevo tag a encontrado:
# 	Help Center
# 	Help Center
# 	traduccion:
# 	Centro de ayuda
# nuevo tag a encontrado:
# 	Contact Us
# 	Contact Us
# 	traduccion:
# 	Contáctenos
# nuevo tag h4 encontrado:
# 	Share
# 	Share
# 	traduccion:
# 	Compartir
# nuevo tag span encontrado:
# 	Facebook
# 	Facebook
# 	traduccion:
# 	Facebook
# nuevo tag span encontrado:
# 	Twitter
# 	Twitter
# 	traduccion:
# 	Gorjeo
# nuevo tag span encontrado:
# 	Email
# 	Email
# 	traduccion:
# 	Correo electrónico
# nuevo tag span encontrado:
# 	Copy link
# 	Copy link
# 	traduccion:
# 	Copiar link
# nuevo tag span encontrado:
# 	Copy link
# 	Copy link
# 	traduccion:
# 	Copiar link

# %% [markdown]
# #### Finally save that file as output

# %%
# Save the translated HTML as a new file
with open(f'website-A_translated_{TARGET_LANGUAGE}.html', 'w', encoding='utf-8') as file:
    file.write(str(soup))
